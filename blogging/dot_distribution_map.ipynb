# %%
import folium
import pandas as pd

# %%
df = pd.read_csv('kc_house_data.csv')
data = df.loc[(df['yr_built'] >= 2000) & (df['yr_built'] < 2010)]
data.head()
# Out:
#             id        date      price  bedrooms  bathrooms  sqft_living  \
# 5   7237550310   5/12/2014  1230000.0         4        4.5         5420
# 9   3793500160   3/12/2015   323000.0         3        2.5         1890
# 29  1873100390    3/2/2015   719000.0         4        2.5         2570
# 30  8562750320  11/10/2014   580500.0         3        2.5         2320
# 31  2426039314   12/1/2014   280000.0         2        1.5         1190
#
#     sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 5     101930     1.0         0.0   0.0     ...         11        3890
# 9       6560     2.0         0.0   0.0     ...          7        1890
# 29      7173     2.0         0.0   0.0     ...          8        2570
# 30      3980     2.0         0.0   0.0     ...          8        2320
# 31      1265     3.0         0.0   0.0     ...          7        1190
#
#     sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
m = folium.Map(location=[47.5480,-121.9836], tiles="Mapbox Bright", zoom_start=10)

# %%
# I can add marker one by one on the map
for i in range(0,len(data)):
   folium.Circle(
      location=[data.iloc[i]['lat'], data.iloc[i]['long']],
      radius=1, #data.iloc[i]['price']*2,
      color='crimson',
      fill=True,
      fill_color='crimson',).add_to(m)
# save it as html
m.save('2000s_map.html')

# %%
data = df.loc[(df['yr_built'] >= 1990) & (df['yr_built'] < 2000)]
data.head()

for i in range(0,len(data)):
   folium.Circle(
      location=[data.iloc[i]['lat'], data.iloc[i]['long']],
      radius=1, #data.iloc[i]['price']*2,
      color='blue',
      fill=True,
      fill_color='crimson',).add_to(m)

# %%
# Save it as html
m.save('1990s_vs_2000s_map.html')
